# %%
pip install requests matplotlib
# Out:
# Requirement already satisfied: requests in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (2.28.1)
# Requirement already satisfied: matplotlib in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (3.7.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from requests) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from requests) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.20 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/meyacarlos/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import time
import matplotlib.pyplot as plt

# Track the location of the ISS

longitude_data = []
latitude_data = []

for i in range(100):
    response = requests.get("http://api.open-notify.org/iss-now.json")
    data = response.json()
    
    longitude = float(data["iss_position"]["longitude"])
    latitude = float(data["iss_position"]["latitude"])
    timestamp = data["timestamp"]
    
    print(longitude)
    print(latitude)
    print(timestamp)
    
    longitude_data.append(longitude)
    latitude_data.append(latitude)
    
    time.sleep(10)
    
# Illustrate the path of the ISS
    
plt.plot(longitude_data, latitude_data)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("ISS Position")
plt.show
# Out:
# -167.9121
# 22.5971
# 1689059339
# -167.4594
# 23.0997
# 1689059350
# -167.0029
# 23.6008
# 1689059360
# -166.5647
# 24.0764
# 1689059370
# -166.1007
# 24.5742
# 1689059381
# -165.655
# 25.0467
# 1689059391
# -165.183
# 25.5411
# 1689059401
# -164.7067
# 26.0337
# 1689059412
# -164.226
# 26.5245
# 1689059423
# -163.764
# 26.99
# 1689059433
# -163.2743
# 27.477
# 1689059443
# -162.78
# 27.9618
# 1689059454
# -162.3047
# 28.4215
# 1689059464
# -161.8007
# 28.9023
# 1689059474
# -161.2916
# 29.3807
# 1689059485
# -160.8019
# 29.8342
# 1689059495
# -160.2826
# 30.308
# 1689059505
# -159.7577
# 30.7795
# 1689059516
# -159.2526
# 31.2261
# 1689059526
# -158.7167
# 31.6926
# 1689059536
# -158.175
# 32.1564
# 1689059547
# -157.6273
# 32.6175
# 1689059557
# -157.0999
# 33.054
# 1689059567
# -156.5402
# 33.5095
# 1689059578
# -155.974
# 33.962
# 1689059588
# -155.4287
# 34.3902
# 1689059598
# -154.8497
